# %% [markdown]
# # Functional Treat

# %%
print("Welcome to The Data Analyzer and Transformer Program !")


while True:
    
    print("\nMain Menu:\n1. Input Data\n2. Display Data Summary (Buil-in Function)\n3. Calculate Factorial (Recursion)\n4. Filter Data by Threshold(Lambda Function)\n5. Sort Data\n6. Display Data Statistics (Return Multiple Values)\n7. Exit")   
    
    try:
        choice = int(input("\nPlease Enter Your Choice:"))
    except ValueError:
        print("Invalid Input")
        continue

    match choice:
        case 1:
            nums = list(map(int, input("Enter numbers: ").split()))
            print("Numbers Entered Successfully...")
            

        case 2:
            print()
            print("List:",nums)
            # Length
            print("Total Elements:",len(nums))
            
            #Sum of the list
            print("Sum of All Elements:",sum(nums))

            # minimum element
            print("Minimum Element:", min(nums))

            # miximum element
            print("Miximum Element:", max(nums))

            # Average The Numbers
            def cal_avg(list):
                total = 0
                for i in nums:
                    total = total + i
                    avg = total / len(nums)
                print("Avrage =", avg)        
            cal_avg(nums)
            print()

        case 3:
            
            ch = int(input("1. Factorial\n2. Fibonnacci\n"))
            
            match ch:
                case 1:
                    # Factorial number Using RECURSION
                    f_num = int(input("Enter The Number To Calculate it Factorial:"))

                    def cal_fact(n):
                        if n == 0 or n ==1:
                            return 1
                        return n * cal_fact(n-1)
                    print("Factorial = ",cal_fact(f_num))
                    break

                case 2:
                    # Fibonacci series
                    f_num = int(input("Enter The Number To Calculate The Fibonnacci:"))

                    def cal_fib(n):
                        if n <= 1:
                            return n
                        return cal_fib(n-1) + cal_fib(n-2)
                    print("Fibonnacci =",cal_fib(f_num))

                case _:
                    print("Enter Valid Input !")

                    break

        case 4:
            if not nums:
                print("No data found")
                continue

            t_val = int(input("Enter threshold value: "))
            result = list(filter(lambda x: x >= t_val, nums))  
            print("Filtered Data:", result)

        case 5:
            print("Choose Sorting Option:\n1. Ascending\n2. Descending\n")
            
            op = int(input("Enter Your Choice:"))

            if op == 1:
                def sort_num(list):
                    list.sort()
                    print(list)
                sort_num(nums)

            elif op == 2:
                def sort_num(list):
                    list.sort(reverse=True)
                    print(list)
                sort_num(nums)

            else:
                print("Enter Valid Input")

        case 6:
            def stats(list):
                return min(list), max(list), sum(list)/len(list)
            mn, mx, avg = ststs(nums)
            print("Min:", mn, "Max:", mx, "Avg:", avg)

        case 7:
            print("Thank You For Using The Data Analyzer and Transformer Program. Goodbye... ")
            break
# Out:
# Welcome to The Data Analyzer and Transformer Program !
#
# Main Menu:
# 1. Input Data
# 2. Display Data Summary (Buil-in Function)
# 3. Calculate Factorial (Recursion)
# 4. Filter Data by Threshold(Lambda Function)
# 5. Sort Data
# 6. Display Data Statistics (Return Multiple Values)
# 7. Exit
# Please Enter Your Choice: 6
# (1, 2, 3, 4, 5, 'Hello')
# {'no': 1, 'name': 'manav'}
#
# Main Menu:
# 1. Input Data
# 2. Display Data Summary (Buil-in Function)
# 3. Calculate Factorial (Recursion)
# 4. Filter Data by Threshold(Lambda Function)
# 5. Sort Data
# 6. Display Data Statistics (Return Multiple Values)
# 7. Exit
