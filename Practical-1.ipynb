# %% [markdown]
# # Fundamental Booster

# %%
# Display a Welcome Message
print("Welcome to the Interactive Personal Data")

# taking name, age, height, and favourite number from the user
name = input("Enter your first name:")
age = int(input("Enter your age:"))
height = float(input("Enter your height in meter:"))
fnum = int(input("Enter your favourite number:"))

#after collecting values from the user give a thank you msg
print("Thank You! Here is the information we collected:")

#print the values, data type and memory address
print("Name:",name, "[","Type:",type(name), "Memory Address:",id(name),"]")
print("Age:",age, "[", "[", "Type:",type(age), "Memory Address:",id(age), "]")
print("Height:",height, "[", "Type:",type(height), "Memory Address:",id(height), "]")
print("Favourite Number:",fnum, "[", "Type:",type(fnum), "Memory Address:",id(fnum), "]")

#Determine the birth year
byear = 2026 - age
print("Your Birth Year is about:", byear)

#showing thank you msg
print("Thank You for using Interactive Personal Data Collector")
# Out:
# Welcome to the Interactive Personal Data
# Enter your first name: manav
# Enter your age: 4
# Enter your height in meter: 1.8
# Enter your favourite number: 7
# Thank You! Here is the information we collected:
# Name: manav [ Type: <class 'str'> Memory Address: 2463516345376 ]
# Age: 4 [ [ Type: <class 'int'> Memory Address: 140713062999048 ]
# Height: 1.8 [ Type: <class 'float'> Memory Address: 2463492616592 ]
# Favourite Number: 7 [ Type: <class 'int'> Memory Address: 140713062999144 ]
# Your Birth Year is about: 2022
# Thank You for using Interactive Personal Data Collector
